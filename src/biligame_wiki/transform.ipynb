# %%
import re

regex = {
    "h": re.compile(r"=+(.+?)=+"),
    "ul": re.compile(r"\*+(.+)："),
    "ol": re.compile(r"\#+(.+)："),
    "a": re.compile(r"\[\[([^文件].+?)\]\]"),
    "icon": re.compile(r"\{\{图标\|(.+?)\}\}"),
}


def save(file: str, data: set[str]):
    with open(file, "w", encoding="utf-8") as f:
        f.write("\n".join(data))


def clean(data: set[str] | list[str]) -> set[str]:
    result = set()
    for word in data:
        transformed_word = ""
        for char in word:
            if is_chinese(char):
                transformed_word += char
            else:
                break
        if len(transformed_word) > 1:
            result.add(transformed_word)

    return result


def is_chinese(char: str) -> bool:
    """检查字符是汉字

    参考: https://cloud.tencent.com/developer/article/1499958
    """
    assert len(char) == 1
    return "\u4e00" <= char <= "\u9fa5"

# %% [markdown]
# ## 天体

# %%
with open("./source_天体.txt", "r", encoding="utf-8") as f:
    source = f.read()

source
# Out:
# '{{面包屑}}\n==主序星==\n主序星是分布在赫罗图对角线附近的主序带上的恒星，宇宙中大部分恒星都是主序星。\n{| class="wikitable wikitable-dsp" border=3 style="margin:10px auto;"\n!分类\n!级别\n!展示\n!style="width: 50em;"|描述\n|-\n|rowspan=2|红矮星\n|[[M型恒星]]||[[文件:M型恒星.png|125px|class=img-star]]\n|质量最低的一类恒星，光芒黯淡偏红，温度也不高。但由于其内部聚变反应速度缓慢，这类恒星的寿命极其漫长。在现有理论中，由于红矮星寿命超过宇宙年龄，当前宇宙中应该不存在红矮星衰老死亡后形成的天体\'\'\'黑矮星\'\'\'。\n\n在游戏中，M型恒星的亮度过低，在其周围建造戴森球是很不划算的。\n|-\n|[[K型恒星]]||[[文件:K型恒星.png|125px|class=img-star]]\n|由于红矮星生命漫长，所以这是宇宙间最常见的恒星，且其数量会随时间的延长而不断增加。由于数目众多，外星生命也有可能出现在这类星系中，但由于红矮星的宜居带太过靠近恒星，红矮星本身活动也不稳定，这里的外星生命将面临恒星活动频繁的考验。\n\n在游戏中，K型恒星的亮度小于1，通常不建议在其周围建造戴森壳，而戴森云因其造价较低，可用于满足星系内的能量需求。\n|-\n|rowspan=2|黄矮星\n|[[G型恒星]]||[[文件:G型恒星.png|125px|class=img-star]]\n|我们的母星太阳，以及游戏开始时抵达的[[地中海]]星球的恒星都是G型恒星，正因如此，G型恒星的光度系数被定义在“1”附近。\n\n由于G型恒星相对稳定，生命有足够时间去演化，因此这类恒星的星系是搜寻外星生命的重点。\n|-\n|[[F型恒星]]||[[文件:F型恒星.png|125px|class=img-star]]\n|F型黄白色的恒星，这类恒星的寿命一般只有30-80亿年，光度和温度都较之G型星更高\nF5以上的恒星，由于寿命短暂，生命可能没有足够的时间去演化\n|-\n|rowspan=3|蓝矮星\n|[[A型恒星]]||[[文件:A型恒星.png|125px|class=img-star]]\n|A型蓝白色恒星，典型的A型恒星寿命一般在30亿年以下，由于A型星的光度变化剧烈，以及强烈的恒星风和辐射，很难存在宜居行星\n|-\n|[[B型恒星]]||[[文件:B型恒星.png|125px|class=img-star]]\n|炽热的蓝色恒星，这类恒星的寿命一般都在10亿年以下，在这里建造的戴森球发电量极高，这类恒星的质量一般都在太阳的8倍以上\n|-\n|[[O型恒星]]||[[文件:O型恒星.png|125px|class=img-star]]\n|O型恒星是游戏里主序星中最亮的种类，其光度往往可以达到2。在O型恒星周围建造的戴森球发电量相当之高。\n|}\n==巨星==\n巨星通常大于10倍太阳直径，并且比其对应的主序星亮度更高。在游戏中，共有红、黄、蓝、白四种巨星，其中红巨星和蓝巨星数量较多，而黄色和白色巨星极其罕见。\n{| class="wikitable wikitable-dsp" border=3 style="margin:10px auto;"\n!级别\n!展示\n!style="width: 50em;"|描述\n|-\n|[[红巨星]]||[[文件:红巨星.png|125px|class=img-star]]\n|\n|-\n|[[黄巨星]]||[[文件:黄巨星.png|125px|class=img-star]]\n|\n|-\n|[[蓝巨星]]||[[文件:蓝巨星.png|125px|class=img-star]]\n|蓝巨星依光谱也分为O型蓝巨和B型蓝巨两种，目前游戏中已知光度最高的一颗恒星便是光度为2.768的一颗蓝巨星（种子id：83028378，64星），在蓝巨上造戴森球是冲发电量排行榜的首选。\n|-\n|[[白巨星]]||[[文件:白巨星.png|125px|class=img-star]]\n|\n|}\n==恒星残骸==\n{| class="wikitable wikitable-dsp" border=3 style="margin:10px auto;"\n!级别\n!展示\n!style="width: 50em;"|描述\n|-\n|[[黑洞]]||[[文件:黑洞.png|125px|class=img-star]]\n|黑洞是超大质量恒星在超新星爆发后的大质量残骸，被事件视界包覆，通常周围环绕有吸积盘。\n\n在游戏中，它们的亮度极低，不适合建造戴森球。\n\n在环绕黑洞或中子星公转的岩质星球上必定可以找到[[单极磁石]]矿脉。\n\n一个星区中只有一颗黑洞。\n|-\n|[[中子星]]||[[文件:中子星.png|125px|class=img-star]]\n|中子星是大质量恒星在超新星爆发后的残骸，主要由中子构成。自转极快，也被称为脉冲星。\n\n在游戏中，它们的亮度过低，不适合建造戴森球。\n\n在环绕中子星或黑洞公转的岩质星球上必定可以找到[[单极磁石]]矿脉。\n\n一个星区中只有一颗中子星。\n|-\n|[[白矮星]]||[[文件:白矮星.png|125px|class=img-star]]\n|白矮星是新星爆发后的残骸，由电子简并态物质构成。我们的太阳在其生命末期就会演化为白矮星。\n\n在游戏中，它们的亮度很低，不适合建造戴森球。\n\n在环绕白矮星公转的岩质星球上必定可以找到[[分形硅石]]、[[金伯利矿石]]和[[光栅石]]矿脉。\n\n在拥有64颗恒星的星区中，通常有2颗白矮星。\n|}\n==[[巨行星]]==\n{| class="wikitable wikitable-dsp" border=3 style="margin:10px auto;"\n!级别\n!展示\n!style="width: 50em;"|描述\n|-\n|[[气态巨星]]||[[文件:类木星气态巨星.gif|125px|class=img-star]]\n|气态巨星在宇宙中相当常见，拥有丰富的[[氢]]和[[重氢]]，可以在其赤道上建造[[轨道采集器]]收集它们。\n|-\n|[[冰巨星]]||[[文件:类海王星冰巨星.gif|125px|class=img-star]]\n|冰巨星较为少见，拥有丰富的[[氢]]和[[可燃冰]]，可以在其赤道上建造[[轨道采集器]]收集它们。\n|}\n==[[岩质行星]]==\n共有20种岩质行星。\n*宜居行星：可以维持生命的行星，轨道在恒星的宜居区。拥有丰富的化石资源，如煤和原油。\n*高温行星：非常热的行星，轨道非常靠近恒星。拥有丰富的金属资源，如铁和钛。\n*荒漠行星：没有任何形式液体的行星，可存在于行星系的任意位置。拥有丰富的非金属资源，如石头、硅和沙土。\n*冻土行星：温度很低，可以在行星系外围找到。拥有丰富的晶体资源，如可燃冰。\n\n表格中列出的稀有矿物仅代表该类型的行星可能拥有这种稀有矿物，并不保证一定生成。\n{| class="wikitable wikitable-dsp" border=3 style="margin:10px auto;"\n!分类\n!名称\n!展示\n!style="width: 50em;"|描述\n|-\n|rowspan=8|宜居行星\n|[[地中海]]||[[文件:行星-地中海.png|125px|class=img-star]]\n|郁郁葱葱的热带宜居世界，被大面积海洋覆盖。\n地中海行星拥有铁铜石煤等基本资源，还有原油，但没有硅和钛。\n\n玩家起始星球必定是地中海。整个星区有且仅有这一颗地中海星球。\n*基础矿物：煤矿、石矿、铜矿、铁矿\n*稀有矿物：原油（必有）\n*海洋：水\n*适建区域：约60%\n*风力：100%\n|-\n|[[海洋丛林]]||[[文件:行星-海洋丛林.png|125px|class=img-star]]\n|宜居世界，有广阔的热带丛林，被大面积海洋覆盖。\n海洋丛林拥有大量有机资源。\n*基础矿物：硅石、煤矿、铁矿、铜矿、石矿\n*稀有矿物：刺笋结晶、原油、有机晶体、金伯利矿石\n*海洋：水\n*适建区域：约50%\n*风力：100%\n|-\n|[[樱林海]]||[[文件:行星-樱林海.png|125px|class=img-star]]\n|美丽的宜居世界。长有含硫酸汁液的奇异植物，被大面积海洋覆盖。\n樱林海的矿物生成和海洋丛林类似，有丰富的有机资源。\n*基础矿物：硅石、煤矿、铁矿、铜矿、石矿\n*稀有矿物：原油（必有）、有机晶体（必有）、刺笋结晶\n*海洋：水\n*适建区域：约65%\n*风力：100%\n|-\n|[[水世界]]||[[文件:行星-水世界.png|125px|class=img-star]]\n|特殊的宜居世界，几乎被海洋彻底覆盖。\n水世界拥有的原油和刺笋结晶资源异常丰富，但布设建筑需要大量的地基和沙土。\n*基础矿物：煤矿\n*稀有矿物：原油（必有）、刺笋结晶（必有）\n*海洋：水\n*适建区域：小于1%\n*风力：110%\n|-\n|[[潘多拉沼泽]]||[[文件:行星-潘多拉沼泽.png|125px|class=img-star]]\n|一个罕见的没有水体的的宜居世界 ...

# %%
h = regex["h"].findall(source)
h
# Out:
# ['主序星',
#  '"wikitable wikitable-dsp" border',
#  '巨星',
#  '"wikitable wikitable-dsp" border',
#  '恒星残骸',
#  '"wikitable wikitable-dsp" border',
#  '[[巨行星]]',
#  '"wikitable wikitable-dsp" border',
#  '[[岩质行星]]',
#  '"wikitable wikitable-dsp" border',
#  '相关概念',
#  '行星词条',
#  '动力学参量']

# %%
h = clean(h)
h
# Out:
# {'主序星', '动力学参量', '巨星', '恒星残骸', '相关概念', '行星词条'}

# %%
ul = regex["ul"].findall(source)
ul
# Out:
# ['宜居行星',
#  '高温行星',
#  '荒漠行星',
#  '冻土行星',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力',
#  '基础矿物',
#  '稀有矿物',
#  '海洋',
#  '适建区域',
#  '风力']

# %%
ul = clean(ul)
ul
# Out:
# {'冻土行星', '基础矿物', '宜居行星', '海洋', '稀有矿物', '荒漠行星', '适建区域', '风力', '高温行星'}

# %%
a = regex["a"].findall(source)
a
# Out:
# ['M型恒星',
#  'K型恒星',
#  'G型恒星',
#  '地中海',
#  'F型恒星',
#  'A型恒星',
#  'B型恒星',
#  'O型恒星',
#  '红巨星',
#  '黄巨星',
#  '蓝巨星',
#  '白巨星',
#  '黑洞',
#  '单极磁石',
#  '中子星',
#  '单极磁石',
#  '白矮星',
#  '分形硅石',
#  '金伯利矿石',
#  '光栅石',
#  '巨行星',
#  '气态巨星',
#  '氢]]和[[重氢',
#  '轨道采集器',
#  '冰巨星',
#  '氢]]和[[可燃冰',
#  '轨道采集器',
#  '岩质行星',
#  '地中海',
#  '海洋丛林',
#  '樱林海',
#  '水世界',
#  '潘多拉沼泽',
#  '红石',
#  '草原',
#  '热带草原',
#  '熔岩',
#  '地热发电站',
#  '火山灰',
#  '戈壁',
#  '贫瘠荒漠',
#  '风力涡轮机',
#  '干旱荒漠',
#  '橙晶荒漠',
#  '黑石盐滩',
#  '飓风石林',
#  '猩红冰湖',
#  '灰烬冻土',
#  '冰原冻土',
#  '极寒冻土',
#  '潮汐锁定',
#  '轨道共振',
#  '横躺自转',
#  '卫星与多卫星',
#  '轨道半径',
#  '公转周期',
#  '自转周期',
#  '轨道倾角',
#  '地轴倾角']

# %%
a = clean(a)
a
# Out:
# {'中子星',
#  '光栅石',
#  '公转周期',
#  '冰原冻土',
#  '冰巨星',
#  '分形硅石',
#  '单极磁石',
#  '卫星与多卫星',
#  '地中海',
#  '地热发电站',
#  '地轴倾角',
#  '岩质行星',
#  '巨行星',
#  '干旱荒漠',
#  '戈壁',
#  '极寒冻土',
#  '横躺自转',
#  '樱林海',
#  '橙晶荒漠',
#  '气态巨星',
#  '水世界',
#  '海洋丛林',
#  '潘多拉沼泽',
#  '潮汐锁定',
#  '火山灰',
#  '灰烬冻土',
#  '热带草原',
#  '熔岩',
#  '猩红冰湖',
#  '白巨星',
#  '白矮星',
#  '红巨星',
#  '红石',
#  '自转周期',
#  '草原',
#  '蓝巨星',
#  '贫瘠荒漠',
#  '轨道倾角',
#  '轨道共振',
#  '轨道半径',
#  '轨道采集器',
#  '金伯利矿石',
#  '风力涡轮机',
#  '飓风石林',
#  '黄巨星',
#  '黑洞',
#  '黑石盐滩'}

# %%
save("dictionary_天体.txt", h | ul | a)

# %% [markdown]
# ## 黑雾

# %%
with open("./source_黑雾.txt", "r", encoding="utf-8") as f:
    source = f.read()

source
# Out:
# '==黑雾简介==\n黑雾属于《戴森球计划》2023年12月15日“黑雾崛起”新资料片更新的敌对势力，对应着游戏主界面的战斗模式。\n==黑雾起源==\n人类在进入虚拟宇宙后，出于对能量的需求，提出了机械能量计划（MEP - Mechanic Energy Program）。\n\n科学家创造了一种具有自我复制功能的机械体，根据计划，机械体将被投入到银河系，攫取能量并提供给主脑。这些机械体在保障主脑能量供应的前提下，可以利用多余的能量及从资源进行自我复制。因此，它们的扩张十分迅速，为了应对银河系中潜在的威胁，科学家们还为机械体设计了强力的防御性武器。\n\n起初机械能量计划的进展十分顺利，机械体为主脑带来了可观的能量。在机械能量计划执行了数年后，主脑陆续发现了一些不寻常的迹象。最初某些机械体上传的超级矩阵被损坏，部分信息出现了混乱并不可解析，发展到后面甚至某些机械上传的信息序列包含自我复制模块并企图劫持主脑的部分计算权限。由于异常的机械体样本量较小，主脑将这些异常判定为随机误差，直到某一天，银河系中所有异常机械体突然切断了与主脑的联系。\n\n由于机械能量计划的技术已经过于落后，为了满足虚拟宇宙的能量需求，人类重组了空间管理联盟（简称：[[COSMO]]）并提出了[[戴森球计划]]。主脑在戴森球计划准备期间秘密地持续对银河系中的信号进行搜寻并解析，试图寻找异常机械体的踪迹。现在主脑综合观察报告，异常能量波动等线索判定，异常机械体的AI模块受到高能射线的影响而进化出了自我意识，它们已经叛变了！这些异常机械体极有可能袭击并阻挠戴森球计划的工作，它们像一团黑色的雾气吞噬一个又一个行星系，因此这些异常机械体有一个流行于工程师中的名字：黑雾（Dark Fog）。\n==黑雾构成==\n黑雾主要由“[[太空巢穴]]”和“[[行星基地]]”两大部分构成，各自有所属的战斗部队和防御设施。\n\n太空巢穴负责能量收集（自带太阳能板以及偷取玩家建设的戴森球能量），行星基地负责物质收集（深入地核），两者通过高空的“[[中继站]]”为纽带互相传递能量和物质（所以攻击中继站会大幅度提高黑雾巢穴的威胁度，同时每个中继站都独立于各自的行星基地和太空巢穴）。注意：正如黑雾无法攻击玩家的运输船一样，玩家也无法攻击这些运输能量和物质的黑雾运输船。\n\n除最初叛变的异常机械体（即游戏开始时便已存在的巢穴和基地）外，随着游戏时间的推移，太空巢穴会逐渐派出新的中继站前往当前星系不同行星建立新的行星基地，随后该中继站便停留在该行星基地的上方充当纽带。随着太空巢穴的发育，它会分化出“[[火种]]”通过太空航行（俗称“硬飞”，不会曲速飞行）前往尚未被太空巢穴占据的星系（在星图模式下可以看到火种的来源和去处）。火种本身不具备攻击力且可以被攻击并消灭，当火种安全到达预定轨道后，会吸收恒星的能量演变成“[[中枢核心]]”（即太空巢穴的核心），形成新的太空巢穴。\n\n中继站通过运输船传递能量和物质，遵循物流系统原则，故其内部会留存一部分能量和物质。当行星基地被摧毁后，停留在高空的中继站会利用该部分资源尝试在原来的[[地核钻井]]处重建行星基地（当玩家在地核钻井处放置地热发电站或用沙土和地基填埋钻井后，中继器会回到所属的太空巢穴）；同样，当太空巢穴被摧毁后，所属中继站也会利用该部分资源尝试重启中枢核心。\n\n所以想要彻底肃清一个星系内的黑雾势力，需要把全部行星基地和太空基地摧毁，并保证没有中继站存在。\n\n==威胁度==\n威胁度，又被玩家戏称为“好感度”。黑雾会根据玩家的发展判断玩家的可能会对黑雾造成的威胁，当威胁度进度条100%时黑雾会派出进攻单位袭击玩家的产线。正常情况下，行星基地的威胁度与玩家发电量有关，发电量越大，威胁度增长速度越快；太空巢穴威胁度与玩家戴森球/戴森云的规模有关，规模越大，威胁度增长越快。攻击[[中继站]]，也会增加太空巢穴的威胁度。\n*{{强调|行星基地袭击逻辑}}：从最短距离前往玩家产线，当袭击单位（游骑兵和强袭者）被消灭时，黑雾来袭结束，该行星基地威胁度清零并重新积累新的威胁度；当来袭的黑雾单位到达预定袭击地方但找不到袭击目标（初期偷矿行为，在黑雾来袭时拆掉所有产线并远离原地）时，黑雾来袭结束，该行星基地威胁度降为40%左右（数据来源自玩家经验而非官方）并重新积累，在此过程中如果黑雾单位被部分消灭，则该行星基地的威胁度将变为40%*（100%-袭击单位损失比例）。\n*{{强调|行星基地威胁度额外}}：当存在黑雾袭击行动时，当前行星其余行星基地威胁度增长速度变为原来的30%左右，以此减少玩家同时被多基地袭击的风险；\n*{{强调|太空巢穴袭击逻辑}}：派出太空进攻单位（枪骑）以太空航行进攻当前星系发电量最大的行星，此时如果未被攻击则到达行星轨道后对产线进行轨道轰炸，如果被攻击则攻击该单位，当袭击单位被消灭时，黑雾来袭结束，该太空巢穴威胁度重新清零；\n*{{强调|太空巢穴威胁度额外}}：当存在黑雾袭击行动时，当前星系其余太空巢穴威胁度增长速度减缓；当有归属于该太空巢穴的中继站被攻击时，该巢穴威胁度大幅度增加。\n*{{强调|[[黑雾进攻波次]]}}：随着行星基地和太空巢穴袭击次数的增加，每波次袭击的单位数量会逐渐增加（与等级无关），行星基地袭击单位上限为180/波次。每波次增加袭击单位的幅度受黑雾攻击性影响。同时，在初始行星上，首次来袭的单位数量比其余行星首次来袭单位要少。\n*[[黑雾防守策略]]\n注：所有行星基地和太空巢穴的威胁度积累独立计算。\n{| class="wikitable-dsp wikitable"\n|+\n!攻击性\n! colspan="5" |地面进攻波次\n! rowspan="4" |\n! colspan="3" |太空进攻波次\n|-\n|\n|0\n|1\n|2\n|3\n|4+\n|1\n|2\n|3+\n|-\n|消极\n|21600\n|288000\n|630000\n|1080000\n|1800000\n|720000\n|1260000\n|1800000\n|-\n|正常\n|9600\n|128000\n|280000\n|480000\n|800000\n|320000\n|560000\n|800000\n|-\n|敏锐\n|6000\n|80000\n|175000\n|300000\n|500000\n!\n|200000\n|350000\n|500000\n|-\n|狂暴\n|3600\n|48000\n|105000\n|180000\n|300000\n!\n|120000\n|210000\n|300000\n|}\n发起一次侵略所需积累的威胁度。地面进攻波次0为初始星球独有。\n\n==[[黑雾掉落]]==\n目前，消灭黑雾地面单位会从残骸中掉落特殊掉落物，其中黑雾矩阵可以让玩家手动研究一些已经被COSMO技术伦理委员会禁止的技术（隐藏[[科技]]），其余特殊掉落物是这些技术所对应设备的生产材料。同时，根据玩家当前的科技，也可以从黑雾残骸中获取常规材料，可以通过战场分析基站查看当前掉落物及数量，也可以通过战场分析基站取消相关材料的掉落。注意，长时间不拾取或垃圾块积累到一定数量后，这些战利品会消失。\n当前太空黑雾单位的掉落物暂无，还需等待新的更新。\n\n==黑雾战斗==\n当前黑雾具有0-30级的等级，在默认难度下，所有黑雾单位初始等级为0级，并在战斗中获取经验逐渐升级30级。注意：黑雾在被动战斗情况下（即玩家主动找黑雾战斗），黑雾经验获取速度增加。黑雾单位等级由其所属的行星基地或太空巢穴等级决定，同时，所有行星基地和太空巢穴会根据等级差缓慢向其他基地和巢穴传递经验（可以跨星系）。\n\n随着等级的提升，各黑雾单位的耐久度、护甲、伤害均会按一定比例提升。\n<div style="max-width: 960px;margin: 0 auto;">\n{| class="wikitable wikitable-dsp" border=3 style="width: 100%;text-align: center"\n|-\n!黑雾单位!!黑雾图标!!黑雾性质!!初始耐久度!!初始护甲!!初始伤害!!每升一级!!备注\n|-\n|{{强调|行星基地}}\n|{{图标|行星基地}}\n|地面核心\n|2000HP\n|0HP\n|无\n|增加120耐久0.2护甲\n|所属设施与单位继承护甲\n|-\n|等离子哨戒塔\n|{{图标|等离子哨戒塔}}\n|内侧防御设施\n|700HP\n|0HP\n|120HP\n|增加55耐久8伤害0.2护甲\n|\n|-\n|未知建筑\n|{{图标|未知建筑}}\n|待下版本补充\n|800HP\n|0HP\n|无\n|增加50耐久0.5护甲\n|单基地最多存在3个。\n|-\n|高能激光塔\n|{{图标|高能激光塔}}\n|外侧防御设施\n|800HP\n|0HP\n|360HP\n|增加60耐久40伤害0.2护甲\n|\n|-\n|守卫者营地\n|{{图标|守卫者营地}}\n|{{图标|守卫者}}\n生产设施\n|800HP\n|0HP\n|无\n|增加50耐久0.2护甲\n|\n|-\n|守卫者\n|{{图标|守卫者}}\n|地面守卫单位\n|48HP\n|0HP\n|16HP\n|增加4耐久2伤害0.2护甲\n|\n|-\n|强袭者营地\n|{{图标|强袭者营地}}\n|{{图标|强袭者}}\n生产设施\n|1000HP\n|0HP\n|无\n|增 ...

# %%
h = regex["h"].findall(source)
h
# Out:
# ['黑雾简介',
#  '黑雾起源',
#  '黑雾构成',
#  '威胁度',
#  '[[黑雾掉落]]',
#  '黑雾战斗',
#  '"wikitable wikitable-dsp" border',
#  '"wikitable wikitable-dsp" border',
#  '击败黑雾后']

# %%
ul = regex["ul"].findall(source)
ul
# Out:
# ['{{强调|行星基地袭击逻辑}}',
#  '{{强调|行星基地威胁度额外}}',
#  '{{强调|太空巢穴袭击逻辑}}',
#  '{{强调|太空巢穴威胁度额外}}',
#  '{{强调|[[黑雾进攻波次]]}}']

# %%
ol = regex["ol"].findall(source)
ol
# Out:
# []

# %%
a = regex["a"].findall(source)
a
# Out:
# ['COSMO',
#  '戴森球计划',
#  '太空巢穴',
#  '行星基地',
#  '中继站',
#  '火种',
#  '中枢核心',
#  '地核钻井',
#  '中继站',
#  '黑雾进攻波次',
#  '黑雾防守策略',
#  '黑雾掉落',
#  '科技',
#  '中继站',
#  '中继站',
#  '火种',
#  '火种',
#  '火种']

# %%
a = clean(a)
a
# Out:
# {'中枢核心',
#  '中继站',
#  '地核钻井',
#  '太空巢穴',
#  '戴森球计划',
#  '火种',
#  '科技',
#  '行星基地',
#  '黑雾掉落',
#  '黑雾进攻波次',
#  '黑雾防守策略'}

# %%
icon = regex["icon"].findall(source)
icon
# Out:
# ['行星基地',
#  '等离子哨戒塔',
#  '未知建筑',
#  '高能激光塔',
#  '守卫者营地',
#  '守卫者',
#  '守卫者',
#  '强袭者营地',
#  '强袭者',
#  '强袭者',
#  '游骑兵营地',
#  '游骑兵',
#  '游骑兵',
#  '中枢核心',
#  '中继站',
#  '光能接收站',
#  '相位激光塔',
#  '等离子发生器',
#  '日蚀要塞装配港',
#  '日蚀要塞',
#  '日蚀要塞',
#  '巨鲸装配港',
#  '巨鲸',
#  '巨鲸',
#  '枪骑装配港',
#  '枪骑',
#  '枪骑',
#  '火种',
#  '地基',
#  '地热发电站']

# %%
icon = clean(icon)
icon
# Out:
# {'中枢核心',
#  '中继站',
#  '光能接收站',
#  '地基',
#  '地热发电站',
#  '守卫者',
#  '守卫者营地',
#  '巨鲸',
#  '巨鲸装配港',
#  '强袭者',
#  '强袭者营地',
#  '日蚀要塞',
#  '日蚀要塞装配港',
#  '未知建筑',
#  '枪骑',
#  '枪骑装配港',
#  '游骑兵',
#  '游骑兵营地',
#  '火种',
#  '相位激光塔',
#  '等离子发生器',
#  '等离子哨戒塔',
#  '行星基地',
#  '高能激光塔'}

# %%
save("dictionary_黑雾.txt", a | icon)

# %% [markdown]
# ## 里程碑

# %%
with open("./source_里程碑.txt", "r", encoding="utf-8") as f:
    source = f.read()

source
# Out:
# '<bstyle>\n.tab-panel{\ncolor: aliceblue;\n}\n.resp-tabs-list li{\nborder-left:1px solid rgba(255 255 255 / 0%);\n}\n.resp-tabs-list li:last-child{\nborder-right:1px solid rgba(255 255 255 / 0%);\n}\n.resp-tabs-list li.active .tab-panel, .tab-panel:hover{\ncolor: rgb(255 255 255 / 85%);\nborder-bottom:2px solid rgb(255 255 255 / 50%);\n}\n.bili-list-style:hover {\nbackground-color: rgba(75, 75, 80, 0.66);\n}\n</bstyle>\n<div style="max-width: 880px;margin: 0 auto;">\n<div class="main-line-wrap">\n<div class="resp-tabs">\n<ul class="resp-tabs-list clearfix" style="margin:15px 5px">\n<li class="active bili-list-style"><span class="tab-panel">总览</span></li>\n<li class="bili-list-style" ><span class="tab-panel" >详细</span></li>\n</ul>\n<div class="resp-tabs-container">\n\n<div class="resp-tab-content" style="display:block">\n{| class="wikitable wikitable-dsp" border=3 style="width: 100%;background:rgba(26,37,43,0.1) ;text-align: center"\n!width=100px|位置（顺时针方向）\n!colspan=4|内容\n|-\n|rowspan=5|上||{{图标|移山填海（里程碑）}}<br/>移山填海\n|-\n|{{图标|射线接收站（里程碑）}}<br/>射线接收站\n|-\n|{{图标|太阳能板（里程碑）}}<br/>太阳能板||{{图标|临界光子（里程碑）}}<br/>临界光子||{{图标|反物质（里程碑）}}<br/>反物质\n|-\n|{{图标|太阳帆（里程碑）}}<br/>太阳帆||{{图标|戴森球细胞（里程碑）}}<br/>戴森球细胞\n|-\n|{{图标|处理器（里程碑）}}<br/>处理器||{{图标|量子芯片（里程碑）}}<br/>量子芯片||{{图标|火箭发射（里程碑）}}<br/>火箭发射\n|-\n|rowspan=6|右||{{图标|化工厂（里程碑）}}<br/>化工厂\n|-\n|colspan=2|{{图标|结构矩阵（里程碑）}}<br/>结构矩阵\n|rowspan=2|{{图标|引力矩阵（里程碑）}}<br/>引力矩阵\n|rowspan=2|{{图标|宇宙矩阵（里程碑）}}<br/>宇宙矩阵\n|-\n|{{图标|电磁矩阵（里程碑）}}<br/>电磁矩阵||{{图标|奇异物质（里程碑）}}<br/>奇异物质\n|-\n|{{图标|能量矩阵（里程碑）}}<br/>能量矩阵||{{图标|信息矩阵（里程碑）}}<br/>信息矩阵\n|-\n|{{图标|重氢（里程碑）}}<br/>重氢||{{图标|卡西米尔晶体（里程碑）}}<br/>卡西米尔晶体\n|-\n|{{图标|液体封装（里程碑）}}<br/>液体封装\n|-\n|rowspan=6|下||{{图标|可燃冰（里程碑）}}<br/>可燃冰||{{图标|有机晶体（里程碑）}}<br/>有机晶体\n|-\n|{{图标|分形硅石（里程碑）}}<br/>分形硅石\n|-\n|{{图标|金伯利矿石（里程碑）}}<br/>金伯利矿石||{{图标|刺笋结晶（里程碑）}}<br/>刺笋结晶\n|-\n|{{图标|光栅石（里程碑）}}<br/>光栅石||{{图标|单极磁石（里程碑）}}<br/>单极磁石\n|-\n|{{图标|宇宙探索（里程碑）}}<br/>宇宙探索\n|-\n|{{图标|低空飞行（里程碑）}}<br/>低空飞行||{{图标|曲速飞行（里程碑）}}<br/>曲速飞行\n|-\n|rowspan=6|左||{{图标|蓝图（里程碑）}}<br/>蓝图\n|-\n|{{图标|风力发电（里程碑）}}<br/>风力发电\n|rowspan=2|{{图标|火力发电（里程碑）}}<br/>火力发电\n|rowspan=2|{{图标|聚变发电（里程碑）}}<br/>聚变发电\n|-\n|\n|-\n|{{图标|行星内物流（里程碑）}}<br/>行星内物流||{{图标|星际物流（里程碑）}}<br/>星际物流||{{图标|轨道采集器（里程碑）}}<br/>轨道采集器\n|-\n|{{图标|自动化（里程碑）}}<br/>自动化||{{图标|人造恒星（里程碑）}}<br/>人造恒星\n|-\n|{{图标|电力储存（里程碑）}}<br/>电力储存||{{图标|能量枢纽（里程碑）}}<br/>能量枢纽\n|}\n</div>\n\n<div class="resp-tab-content">\n{| class="wikitable wikitable-dsp" border=3 style="width: 100%;background:rgba(26,37,43,0.1) ;text-align: center"\n!分类\n!width=75px|里程碑!!描述文字（未达成里程碑）!!达成条件!!描述文字（达成里程碑）!!相关科技与组件\n|-\n|rowspan=3|宇宙探索||{{图标|低空飞行（里程碑）}}<br/>低空飞行\n|你完成了一次低空飞行。这是一次飞跃，它加快了你前进的脚步，让你离太空越来越近! \n|进行一次低空飞行\n|你完成了一次低空飞行，飞行距离{{黑幕|数字}}米。这是一次飞跃，它加快了你前进的脚步，让你离太空越来越近!\n|{{图标|驱动引擎（1）}}\n|-\n|{{图标|宇宙探索（里程碑）}} <br/>宇宙探索\n|你登陆了一颗新的行星，迈出了宇宙探索的第一步。太空的浩瀚无垠，一次星际旅行，一切都妙不可言。\n|离开初始行星，登陆另一个陆地行星。\n|你跨越了{{黑幕|数字}}AU 的距离，登陆了行星{{黑幕|默认名称}}{{黑幕|，并将其命名为新名称}}，迈出了宇宙探索的第一步。太空的浩瀚无垠，一次星际旅行，一切都妙不可言。\n|{{图标|驱动引擎（2）}}\n|-\n|{{图标|曲速飞行（里程碑）}}<br/>曲速飞行\n|你完成了一次曲速飞行，曲率引擎的诞生拉进了行星系之间的距离，整个宇宙都在你的脚下，什么时候都可以来一场说走就走的旅行! \n|进行一次跨星系曲速飞行\n|你完成了一次曲速飞行，跨越了{{黑幕|数字}}光年的距离，从{{黑幕|某某行星系或外太空}}来到了{{黑幕|某某行星系或外太空}}。曲率引擎的诞生拉近了行星系之间的距离，整个宇宙都在你的脚下，什么时候都可以来一场说走就走的旅行! \n|{{图标|驱动引擎（4）}}\n|-\n|rowspan=7|珍奇||{{图标|可燃冰（里程碑）}}<br/>可燃冰\n|你采集了可燃冰，宇宙珍奇之一。它在宇宙中广泛存在，找到它，可以大大提高生产石墨烯的效率。\n|找到并采集一个可燃冰<br/>注：在冰巨星手动采集，或用轨道采集器采集到也可。\n|你在{{黑幕|某地}}上发现并开采了可燃冰，宇宙珍奇之一。它在宇宙中广泛存在，找到它，可以大大提高生产石墨烯的效率。\n|{{图标|轨道采集器}}{{图标|可燃冰矿}}\n|-\n|{{图标|金伯利矿石（里程碑）}}<br/>金伯利矿石\n|你采集了金伯利矿石，宇宙珍奇之一，它是金伯利岩浆直接结晶而成的矿石。\n|找到金伯利矿脉并采集\n|你在{{黑幕|某地}}上发现并开采了金伯利矿石，宇宙珍奇之一，它是金伯利岩浆直接结晶而成的矿石。\n|{{图标|金伯利矿脉}}\n|-\n|{{图标|分形硅石（里程碑）}}<br/>分形硅石\n|你采集了分形硅石，宇宙珍奇之一。你不禁感叹，宇宙中竟然存在拥有如此完美分形结构的矿石! \n|达成条件：找到分形硅石矿脉并采集\n|你在{{黑幕|某地}}上发现并开采了分形硅石，宇宙珍奇之一。你不禁感叹，宇宙中竟然存在拥有如此完美分形结构的矿石! \n|{{图标|分形硅矿}}\n|-\n|{{图标|光栅石（里程碑）}}<br/>光栅石\n|你采集了光栅石，宇宙珍奇之一，它表面拥有天然的刻槽，是制造光学元件不可多得的原材料。\n|找到光栅石矿脉并采集\n|你在{{黑幕|某地}}上发现并开采了光栅石，宇宙珍奇之一，它表面拥有天然的刻槽，是制造光学元件不可多得的原材料。\n|{{图标|光栅石矿}}\n|-\n|{{图标|刺笋结晶（里程碑）}}<br/>刺笋结晶\n|你采集了刺笋结晶，宇宙珍奇之一，它是无数逝去的海洋生物生命的沉淀! \n|找到刺笋结晶矿脉并采集"\n|你在{{黑幕|某地}}上发现并开采了刺笋 ...

# %%
icon = regex["icon"].findall(source)
icon
# Out:
# ['移山填海（里程碑）',
#  '射线接收站（里程碑）',
#  '太阳能板（里程碑）',
#  '临界光子（里程碑）',
#  '反物质（里程碑）',
#  '太阳帆（里程碑）',
#  '戴森球细胞（里程碑）',
#  '处理器（里程碑）',
#  '量子芯片（里程碑）',
#  '火箭发射（里程碑）',
#  '化工厂（里程碑）',
#  '结构矩阵（里程碑）',
#  '引力矩阵（里程碑）',
#  '宇宙矩阵（里程碑）',
#  '电磁矩阵（里程碑）',
#  '奇异物质（里程碑）',
#  '能量矩阵（里程碑）',
#  '信息矩阵（里程碑）',
#  '重氢（里程碑）',
#  '卡西米尔晶体（里程碑）',
#  '液体封装（里程碑）',
#  '可燃冰（里程碑）',
#  '有机晶体（里程碑）',
#  '分形硅石（里程碑）',
#  '金伯利矿石（里程碑）',
#  '刺笋结晶（里程碑）',
#  '光栅石（里程碑）',
#  '单极磁石（里程碑）',
#  '宇宙探索（里程碑）',
#  '低空飞行（里程碑）',
#  '曲速飞行（里程碑）',
#  '蓝图（里程碑）',
#  '风力发电（里程碑）',
#  '火力发电（里程碑）',
#  '聚变发电（里程碑）',
#  '行星内物流（里程碑）',
#  '星际物流（里程碑）',
#  '轨道采集器（里程碑）',
#  '自动化（里程碑）',
#  '人造恒星（里程碑）',
#  '电力储存（里程碑）',
#  '能量枢纽（里程碑）',
#  '低空飞行（里程碑）',
#  '驱动引擎（1）',
#  '宇宙探索（里程碑）',
#  '驱动引擎（2）',
#  '曲速飞行（里程碑）',
#  '驱动引擎（4）',
#  '可燃冰（里程碑）',
#  '轨道采集器',
#  '可燃冰矿',
#  '金伯利矿石（里程碑）',
#  '金伯利矿脉',
#  '分形硅石（里程碑）',
#  '分形硅矿',
#  '光栅石（里程碑）',
#  '光栅石矿',
#  '刺笋结晶（里程碑）',
#  '刺笋结晶矿',
#  '单极磁石（里程碑）',
#  '单极磁矿',
#  '有机晶体（里程碑）',
#  '有机晶体矿',
#  '电磁矩阵（里程碑）',
#  '电磁矩阵',
#  '能量矩阵（里程碑）',
#  '能量矩阵',
#  '结构矩阵（里程碑）',
#  '结构矩阵',
#  '信息矩阵（里程碑）',
#  '信息矩阵',
#  '引力矩阵（里程碑）',
#  '引力矩阵',
#  '宇宙矩阵（里程碑）',
#  '宇宙矩阵',
#  '处理器（里程碑）',
#  '处理器',
#  '卡西米尔晶体（里程碑）',
#  '卡西米尔晶体',
#  '奇异物质（里程碑）',
#  '奇异物质',
#  '量子芯片（里程碑）',
#  '量子芯片',
#  '临界光子（里程碑）',
#  '临界光子',
#  '反物质（里程碑）',
#  '反物质',
#  '自动化（里程碑）',
#  '行星内物流（里程碑）',
#  '行星内物流运输站',
#  '星际物流（里程碑）',
#  '星际物流运输站',
#  '轨道采集器（里程碑）',
#  '轨道采集器',
#  '风力发电（里程碑）',
#  '风力涡轮机',
#  '火力发电（里程碑）',
#  '火力发电厂',
#  '聚变发电（里程碑）',
#  '微型聚变发电站',
#  '电力储存（里程碑）',
#  '蓄电器（满）',
#  '能量枢纽（里程碑）',
#  '能量枢纽',
#  '人造恒星（里程碑）',
#  '人造恒星',
#  '化工厂（里程碑）',
#  '化工厂',
#  '蓝图（里程碑）',
#  '液体封装（里程碑）',
#  '移山填海（里程碑）',
#  '地基',
#  '重氢（里程碑）',
#  '重氢',
#  '太阳能板（里程碑）',
#  '太阳能板',
#  '太阳帆（里程碑）',
#  '太阳帆',
#  '射线接收站（里程碑）',
#  '射线接收站',
#  '火箭发射（里程碑）',
#  '垂直发射井',
#  '戴森球细胞（里程碑）']

# %%
icon = clean(icon)
icon
# Out:
# {'临界光子',
#  '人造恒星',
#  '低空飞行',
#  '信息矩阵',
#  '光栅石',
#  '光栅石矿',
#  '分形硅石',
#  '分形硅矿',
#  '刺笋结晶',
#  '刺笋结晶矿',
#  '化工厂',
#  '单极磁石',
#  '单极磁矿',
#  '卡西米尔晶体',
#  '反物质',
#  '可燃冰',
#  '可燃冰矿',
#  '地基',
#  '垂直发射井',
#  '处理器',
#  '太阳帆',
#  '太阳能板',
#  '奇异物质',
#  '宇宙探索',
#  '宇宙矩阵',
#  '射线接收站',
#  '引力矩阵',
#  '微型聚变发电站',
#  '戴森球细胞',
#  '星际物流',
#  '星际物流运输站',
#  '曲速飞行',
#  '有机晶体',
#  '有机晶体矿',
#  '液体封装',
#  '火力发电',
#  '火力发电厂',
#  '火箭发射',
#  '电力储存',
#  '电磁矩阵',
#  '移山填海',
#  '结构矩阵',
#  '聚变发电',
#  '能量枢纽',
#  '能量矩阵',
#  '自动化',
#  '蓄电器',
#  '蓝图',
#  '行星内物流',
#  '行星内物流运输站',
#  '轨道采集器',
#  '重氢',
#  '量子芯片',
#  '金伯利矿石',
#  '金伯利矿脉',
#  '风力发电',
#  '风力涡轮机',
#  '驱动引擎'}

# %%
save("dictionary_里程碑.txt", icon)
